# %% [markdown]
# ## Libraries

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %% [markdown]
# ## Dataset

# %%
dataset = pd.read_csv(r"C:\Users\PMLS\Downloads\updated_milk_adulteration_dataset1.csv")

# %%
dataset.tail(500)
# Out:
#         pH   Fat  Lactose  Protein  Gravity    SNF  Temperature     Gas  \
# 3743  7.33  1.49     3.39     1.15    21.99   4.63        16.05   81.93
# 3744  6.89  1.85     3.01     1.15    18.12   3.98        18.70   78.58
# 3745  6.80  1.18     2.87     1.89    19.43   3.27        26.81   85.97
# 3746  6.89  2.19     3.18     1.02    21.21   3.66        22.67   49.35
# 3747  6.84  1.19     2.78     1.36    19.47   4.06        26.55   71.48
# ...    ...   ...      ...      ...      ...    ...          ...     ...
# 4238  6.39  4.53     2.43     7.67    16.28   8.59        24.78  113.85
# 4239  6.68  2.84     5.62     1.42    14.38  13.28        27.83   82.07
# 4240  6.72  3.21     5.96     4.20    42.67  17.51        28.11  163.30
# 4241  4.23  6.10     5.21     1.31    19.75  20.25        24.01  165.55
# 4242  6.98  4.32     6.47     3.96    55.79   4.49        24.67  127.53
#
#          EC         Class
# 3743   1.64         Water
# 3744   1.11         Water
# ...

# %% [markdown]
# ## Columns

# %%
df = dataset[['Lactose', 'Fat', 'SNF', 'Protein', 'Gravity', 'pH', 'Temperature', 'Gas', 'EC', 'Class']]

df.tail(50)
# Out:
#       Lactose    Fat    SNF  Protein  Gravity     pH  Temperature     Gas  \
# 4193     2.99   2.66  28.94     4.59    44.24   3.92        20.59  127.07
# 4194     4.31   7.21  18.94     4.10    22.41   7.46        27.64   88.14
# 4195     6.05   2.65   8.91     4.01    52.84   4.22        27.24  144.78
# 4196     9.57   4.20  18.43     4.56    50.84   4.79        27.17  133.57
# 4197     7.95   4.98   7.51     1.90    62.64   5.13        25.97  109.15
# 4198     4.29   3.40   9.44     0.74    69.29   4.82        23.14   86.04
# 4199     8.33   4.93  18.68     1.48    20.30   4.66        27.80  183.68
# 4200     3.58   4.28  18.39     4.36     9.09   6.28        29.36  183.24
# 4201     7.56   3.61  18.27     3.52    43.82   9.53        25.59  123.27
# 4202     6.96   4.39  11.84     6.79    31.68   4.90        28.16  185.52
# 4203     4.62   6.43  19.05     4.09    42.04   5.37        24.17  172.08
# 4204     9.31   1.35  19.97     4.52    44.92   7.42        23.70  211.99
# ...

# %% [raw]
# ## Dataset Information

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 4243 entries, 0 to 4242
# Data columns (total 10 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   Lactose      4243 non-null   float64
#  1   Fat          4243 non-null   float64
#  2   SNF          4243 non-null   float64
#  3   Protein      4243 non-null   float64
#  4   Gravity      4243 non-null   float64
#  5   pH           4243 non-null   float64
#  6   Temperature  4243 non-null   float64
#  7   Gas          4243 non-null   float64
#  8   EC           4243 non-null   float64
#  9   Class        4243 non-null   object
# dtypes: float64(9), object(1)
# memory usage: 331.6+ KB

# %% [markdown]
# ## Missing Values in Dataset

# %%
df.isnull().sum()
# Out:
# Lactose        0
# Fat            0
# SNF            0
# Protein        0
# Gravity        0
# pH             0
# Temperature    0
# Gas            0
# EC             0
# Class          0
# dtype: int64

# %% [markdown]
# ## Unique Values in 'Class' Column

# %%
df['Class'].unique()
# Out:
# array(['Pure', 'Urea', 'Starch', 'Maltodextrin', 'Sodium Bicarbonate',
#        'Formaldehyde', 'Water'], dtype=object)

# %% [markdown]
# ## Values Counts

# %%
df['Class'].value_counts()
# Out:
# Class
# Sodium Bicarbonate    610
# Formaldehyde          610
# Pure                  609
# Maltodextrin          606
# Urea                  605
# Water                 602
# Starch                601
# Name: count, dtype: int64

# %% [markdown]
# ## Summary Statistics

# %%
df.describe()
# Out:
#            Lactose          Fat          SNF      Protein      Gravity  \
# count  4243.000000  4243.000000  4243.000000  4243.000000  4243.000000
# mean      5.609380     4.723040    13.826847     4.068032    45.304087
# std       2.025217     2.001407     6.580008     1.844695    19.003803
# min       0.390000    -0.570000    -8.370000    -2.090000    -8.770000
# 25%       3.380000     3.160000     8.790000     1.890000    29.540000
# 50%       5.950000     4.530000    12.500000     4.240000    41.090000
# 75%       7.240000     6.300000    20.490000     5.630000    67.395000
# max      11.020000    11.770000    29.440000     8.260000    92.860000
#
#                 pH  Temperature          Gas           EC
# count  4243.000000  4243.000000  4243.000000  4243.000000
# mean      5.488126    25.953717   126.613436     5.298492
# std       1.554156     3.616917    50.602072     6.067693
# min       1.600000    14.840000    -1.620000    -9.430000
# ...

# %% [markdown]
# ## Histogram of Numerical Feature Distributions

# %%
sns.set(style="whitegrid")

df.hist(bins=15, figsize=(15, 10))
plt.suptitle("Distribution of Numerical Features", fontsize=16)
plt.tight_layout()
plt.show()

# %% [markdown]
# ## Pairplot of Features by Class

# %%
sns.pairplot(df, hue='Class', markers=["o", "s", "D", "P", "X", "v"], diag_kind='kde')
plt.suptitle("Pairplot of Features by Class", y=1.02)
plt.show()
# Out:
# C:\Users\PMLS\anaconda3\Lib\site-packages\seaborn\axisgrid.py:1615: UserWarning:
# The markers list has fewer values (6) than needed (7) and will cycle, which may produce an uninterpretable plot.
#   func(x=x, y=y, **kwargs)
# C:\Users\PMLS\anaconda3\Lib\site-packages\seaborn\axisgrid.py:1615: UserWarning:
# The markers list has fewer values (6) than needed (7) and will cycle, which may produce an uninterpretable plot.
#   func(x=x, y=y, **kwargs)
# C:\Users\PMLS\anaconda3\Lib\site-packages\seaborn\axisgrid.py:1615: UserWarning:
# The markers list has fewer values (6) than needed (7) and will cycle, which may produce an uninterpretable plot.
#   func(x=x, y=y, **kwargs)
# C:\Users\PMLS\anaconda3\Lib\site-packages\seaborn\axisgrid.py:1615: UserWarning:
# The markers list has fewer values (6) than needed (7) and will cycle, which may produce an uninterpretable plot.
#   func(x=x, y=y, **kwargs)
# C:\Users\PMLS\anaconda3\Lib\site-packages\seaborn\axisgrid.py:1615: UserWarning:
# ...

# %% [markdown]
# ## Countplot for the Class

# %%
# Countplot for the target variable Class
plt.figure(figsize=(10, 6))
color = ['r', 'g', 'b', 'k', 'y', 'm']
sns.countplot(data=df, x='Class', palette=color)
plt.title("Distribution of Classes")
plt.xlabel("Class")
plt.ylabel("Count")
plt.show()
# Out:
# C:\Users\PMLS\AppData\Local\Temp\ipykernel_13720\4132214960.py:4: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.countplot(data=df, x='Class', palette=color)
# C:\Users\PMLS\AppData\Local\Temp\ipykernel_13720\4132214960.py:4: UserWarning:
# The palette list has fewer values (6) than needed (7) and will cycle, which may produce an uninterpretable plot.
#   sns.countplot(data=df, x='Class', palette=color)

# %% [markdown]
# ##  Scatter plot between Lactose and Fat

# %%
plt.figure(figsize=(10, 6))
sns.scatterplot(data=df, x='Lactose', y='Fat', hue='Class', style='Class', s=100)
plt.title("Scatter Plot of Lactose vs Fat")
plt.xlabel("Lactose")
plt.ylabel("Fat")
plt.legend(title='Class')
plt.show()

# %% [markdown]
# ## Label Encoding of Class Column

# %%
from sklearn.preprocessing import LabelEncoder

# %%
label_encoder = LabelEncoder()

df['Class'] = label_encoder.fit_transform(df['Class'])

# %% [markdown]
# ## After encoding

# %%
df['Class'].unique()
# Out:
# array([2, 5, 4, 1, 3, 0, 6])

# %% [markdown]
# ## Splitting Data into Features and Target

# %%
input_data_x = df.iloc[: , : -1]

output_data_y = df['Class']

# %% [markdown]
# ## Features Scaling

# %%
from sklearn.preprocessing import StandardScaler

# %%
ss = StandardScaler()

input_data_x = pd.DataFrame(ss.fit_transform(input_data_x) , columns=input_data_x.columns)

# %%
input_data_x
# Out:
#        Lactose       Fat       SNF   Protein   Gravity        pH  Temperature  \
# 0    -0.424390  0.932934 -0.811165 -0.085679 -0.908561  0.779855    -2.951402
# 1    -0.093522  1.642518 -0.873483 -0.085679 -0.805938  0.728374     0.189765
# 2    -0.152782  0.862975 -0.867403 -0.237483 -0.886458  0.869947    -1.181730
# 3    -0.370068  0.738048 -0.853724 -0.204954 -0.880143  0.895688    -0.504278
# 4    -0.310808  1.702483 -0.853724 -0.139894 -0.891721  0.799161    -2.061036
# ...        ...       ...       ...       ...       ...       ...          ...
# 4238 -1.570081 -0.096464 -0.795966  1.952840 -1.527458  0.580367    -0.324546
# 4239  0.005244 -0.940969 -0.083117 -1.435655 -1.627450  0.766985     0.518813
# 4240  0.173147 -0.756077  0.559815  0.071548 -0.138625  0.792726     0.596236
# 4241 -0.197227  0.688077  0.976277 -1.495292 -1.344841 -0.809620    -0.537459
# 4242  0.425002 -0.201402 -1.419139 -0.058571  0.551845  0.960039    -0.354962
#
#            Gas        EC
# ...

# %% [markdown]
# ## Splitting the Data into Training and Testing Sets

# %%
from sklearn.model_selection import train_test_split 

X_train , X_test , y_train , y_test = train_test_split(input_data_x , output_data_y , test_size=0.2 , random_state=40)

# %% [markdown]
# ## Training the Random Forest Classifier Model

# %%
from sklearn.ensemble import RandomForestClassifier

# %%
RF_model = RandomForestClassifier(
    n_estimators=200,    
    max_depth=4,          
    min_samples_split=10,  
    min_samples_leaf=5,    
    max_features='sqrt',    
    bootstrap=True,         
)

# %%
RF_model.fit(X_train , y_train)
# Out:
# RandomForestClassifier(max_depth=4, min_samples_leaf=5, min_samples_split=10,
#                        n_estimators=200)

# %% [markdown]
# ## Evaluating Model Performance

# %%
train_score = RF_model.score(X_train, y_train) * 100
test_score = RF_model.score(X_test, y_test) * 100

# %%
print(f"Train Score: {train_score:.2f}%")
print(f"Test Score: {test_score:.2f}%")
# Out:
# Train Score: 96.17%
# Test Score: 95.41%

# %%
from sklearn.metrics import mean_squared_error , mean_absolute_error

# %%
mse = mean_squared_error(y_test, RF_model.predict(X_test))
mae = mean_absolute_error(y_test, RF_model.predict(X_test))

# %%
print(f"Mean Squared Error: {mse:.2f}")
print(f"Mean Absolute Error: {mae:.2f}")
# Out:
# Mean Squared Error: 0.37
# Mean Absolute Error: 0.11

# %%
X_test
# Out:
#        Lactose       Fat       SNF   Protein   Gravity        pH  Temperature  \
# 3297  0.326235  1.467621  0.330305  1.410681  0.335020 -2.038728     0.021093
# 3475 -1.179953 -1.820454 -1.469297 -1.376017 -1.384312  0.876382    -2.061036
# 823   1.071922 -0.836031 -0.130235  0.537804 -0.278087 -0.018100     0.549230
# 70   -0.261425  1.362682 -0.871963 -0.145316 -0.805938  0.683329    -2.343077
# 2554 -1.283658 -0.995937  1.526493 -1.511557  1.549131  0.786290     0.366732
# ...        ...       ...       ...       ...       ...       ...          ...
# 1480 -0.044139  0.013472 -0.464621 -0.031463 -0.595956 -0.474993     0.665364
# 3004  0.548460  1.152805  0.435180  1.410681  0.287656 -2.019422     0.115107
# 3987 -1.224398 -1.800466 -1.394820 -1.186261 -1.389048  0.940733    -2.069331
# 4178  1.195380 -1.045908 -0.488939  0.451059  0.543424 -0.725963     1.240507
# 985   0.968218 -0.751080 -0.187993  0.684187 -0.182305 -0.024535     0.250597
#
#            Gas        EC
# ...

# %%
RF_model.predict([[0.310741,	0.596366	,1.655307	,0.608921	,1.152050	,0.963616	,0.911996	,-0.407817	,-0.368142]])
# Out:
# C:\Users\PMLS\anaconda3\Lib\site-packages\sklearn\base.py:493: UserWarning: X does not have valid feature names, but RandomForestClassifier was fitted with feature names
#   warnings.warn(
# array([1])

# %%
y_test
# Out:
# 3297    0
# 3475    6
# 823     5
# 70      2
# 2554    3
#        ..
# 1480    4
# 3004    0
# 3987    6
# 4178    1
# 985     5
# Name: Class, Length: 849, dtype: int32

# %% [markdown]
# Lactose Fat  SNF   Protein Gravity pH   Temperature Gas   EC
# 13.13   5.90 21.20 10.00   68.33   5.79 25.94    23.46   3.01

# %%
new_data = pd.DataFrame([[	04.07, 02.70, 07.43, 02.73, 24.79, 	11, 	34.75 , 357.00, 5.85]] , columns=X_train.columns)

new_data
# Out:
#    Lactose  Fat   SNF  Protein  Gravity  pH  Temperature    Gas    EC
# 0     4.07  2.7  7.43     2.73    24.79  11        34.75  357.0  5.85

# %%
ss.transform(new_data)
# Out:
# array([[-0.76019577, -1.01092825, -0.97227849, -0.72542621, -1.07959994,
#          3.54695736,  2.43227054,  4.55344431,  0.0909033 ]])

# %%
new_data = pd.DataFrame(ss.transform(new_data) , columns = new_data.columns)
new_data
# Out:
#     Lactose       Fat       SNF   Protein  Gravity        pH  Temperature  \
# 0 -0.760196 -1.010928 -0.972278 -0.725426  -1.0796  3.546957     2.432271
#
#         Gas        EC
# 0  4.553444  0.090903

# %%
prediction = RF_model.predict(new_data)

# %%
prediction
# Out:
# array([2])

# %%
if prediction[0] == 2:
    print("Milk is Pure")
elif prediction[0] == 5:
    print("Milk is Adulterated with Urea")
elif prediction[0] == 4:
    print("Milk is Adulterated with Starch")
elif prediction[0] == 1:
    print("Milk is Adulterated with Maltodextrin")
elif prediction[0] == 3:
    print("Milk is Adulterated with Sodium Bicarbonate")
elif prediction[0] == 0:
    print("Milk is Adulterated with Formaldehyde")
elif prediction[0] == 6:
    print("Milk is Adulterated with Water")
else:
    print("Unknown result")
# Out:
# Milk is Pure

# %%
import joblib

model_path = "milk_adulteration_model.pkl"
joblib.dump(RF_model, model_path)
print(f"Model saved as {model_path}")



scaler_path = "scaler.pkl"
joblib.dump(ss, scaler_path)
print(f"Scaler saved as {scaler_path}")
# Out:
# Model saved as milk_adulteration_model.pkl
# Scaler saved as scaler.pkl
